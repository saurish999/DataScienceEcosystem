# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### Summary of Data Science Tools and Ecosystems

# %% [markdown]
# Objectives
# - List popular languages in data science
# - List the common libraries used in data science
# - Data Science Tools
# - Evaluating arithmetic expressions in Python
# - Converting minutes into hours using Python

# %% [markdown]
# Some of the popular Data Science languages include
# 1. Python
# 2. SQL
# 3. R

# %% [markdown]
# Some of the common libraries used by data scientists include:
# 1. Numpy
# 2. Matplotlib
# 3. Pandas
# 4. ggplot

# %% [markdown]
# | Data Science Tools |
# | --------------------|
# | Jupyter Notebook |
# | Google Colab |
# | RStudio |

# %% [markdown]
# ### Few examples of evaluating arithmetic expressions in Python

# %%
#Example of Arithmetic Expression to multiply then add

(3*4) +5
# Out:
# 17

# %%
# Converting minutes into hours

minutes = 200
hours = minutes / 60
print("200 minutes =",hours,"hours")
# Out:
# 200 minutes = 3.3333333333333335 hours

# %% [markdown]
# ## Author
# Saurish
